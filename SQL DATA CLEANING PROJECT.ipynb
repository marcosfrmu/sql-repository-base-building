# %% [markdown]
# ## ANALISIS DE LAS BASES DE DATOS
# ## PASO 1: INVESTIGACIÓN
#
# 1. En primer lugar hemos hecho un análisis de las distintas bases de datos.
# 2. Hacemos una copia de todos los dataframe para mayor seguridad. Las copias se van a llamar como los originales pero en plural, para diferenciar entre columnas (singular y minúscula) y dataframes (plural y minúscula)

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
actor= pd.read_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\data\actor.csv')

# %%
actors=actor.copy()

# %%
actors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   actor_id     200 non-null    int64
#  1   first_name   200 non-null    object
#  2   last_name    200 non-null    object
#  3   last_update  200 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 6.4+ KB

# %%
actors.head(50)
# Out:
#     actor_id first_name     last_name          last_update
# 0          1   PENELOPE       GUINESS  2006-02-15 04:34:33
# 1          2       NICK      WAHLBERG  2006-02-15 04:34:33
# 2          3         ED         CHASE  2006-02-15 04:34:33
# 3          4   JENNIFER         DAVIS  2006-02-15 04:34:33
# 4          5     JOHNNY  LOLLOBRIGIDA  2006-02-15 04:34:33
# 5          6      BETTE     NICHOLSON  2006-02-15 04:34:33
# 6          7      GRACE        MOSTEL  2006-02-15 04:34:33
# 7          8    MATTHEW     JOHANSSON  2006-02-15 04:34:33
# 8          9        JOE         SWANK  2006-02-15 04:34:33
# 9         10  CHRISTIAN         GABLE  2006-02-15 04:34:33
# 10        11       ZERO          CAGE  2006-02-15 04:34:33
# 11        12       KARL         BERRY  2006-02-15 04:34:33
# 12        13        UMA          WOOD  2006-02-15 04:34:33
# 13        14     VIVIEN        BERGEN  2006-02-15 04:34:33
# 14        15       CUBA       OLIVIER  2006-02-15 04:34:33
# ...

# %%
category=pd.read_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\data\category.csv')

# %%
categories=category.copy()

# %%
categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category_id  16 non-null     int64
#  1   name         16 non-null     object
#  2   last_update  16 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 512.0+ bytes

# %%
categories
# Out:
#     category_id         name          last_update
# 0             1       Action  2006-02-15 04:46:27
# 1             2    Animation  2006-02-15 04:46:27
# 2             3     Children  2006-02-15 04:46:27
# 3             4     Classics  2006-02-15 04:46:27
# 4             5       Comedy  2006-02-15 04:46:27
# 5             6  Documentary  2006-02-15 04:46:27
# 6             7        Drama  2006-02-15 04:46:27
# 7             8       Family  2006-02-15 04:46:27
# 8             9      Foreign  2006-02-15 04:46:27
# 9            10        Games  2006-02-15 04:46:27
# 10           11       Horror  2006-02-15 04:46:27
# 11           12        Music  2006-02-15 04:46:27
# 12           13          New  2006-02-15 04:46:27
# 13           14       Sci-Fi  2006-02-15 04:46:27
# 14           15       Sports  2006-02-15 04:46:27
# 15           16       Travel  2006-02-15 04:46:27

# %%
film= pd.read_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\data\film.csv')

# %%
films= film.copy()

# %%
films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   film_id               1000 non-null   int64
#  1   title                 1000 non-null   object
#  2   description           1000 non-null   object
#  3   release_year          1000 non-null   int64
#  4   language_id           1000 non-null   int64
#  5   original_language_id  0 non-null      float64
#  6   rental_duration       1000 non-null   int64
#  7   rental_rate           1000 non-null   float64
#  8   length                1000 non-null   int64
#  9   replacement_cost      1000 non-null   float64
#  10  rating                1000 non-null   object
#  11  special_features      1000 non-null   object
#  12  last_update           1000 non-null   object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 101.7+ KB

# %%
films.head(50)
# Out:
#     film_id                        title  \
# 0         1             ACADEMY DINOSAUR
# 1         2               ACE GOLDFINGER
# 2         3             ADAPTATION HOLES
# 3         4             AFFAIR PREJUDICE
# 4         5                  AFRICAN EGG
# 5         6                 AGENT TRUMAN
# 6         7              AIRPLANE SIERRA
# 7         8              AIRPORT POLLOCK
# 8         9                ALABAMA DEVIL
# 9        10             ALADDIN CALENDAR
# 10       11              ALAMO VIDEOTAPE
# 11       12               ALASKA PHANTOM
# 12       13                  ALI FOREVER
# 13       14               ALICE FANTASIA
# 14       15                 ALIEN CENTER
# 15       16              ALLEY EVOLUTION
# 16       17                   ALONE TRIP
# 17       18                ALTER VICTORY
# 18       19                 AMADEUS HOLY
# 19       20          AMELIE HELLFIGHTERS
# 20       21              AMERICAN CIRCUS
# 21       22            AMISTAD MIDSUMMER
# ...

# %%
inventory=pd.read_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\data\inventory.csv')

# %%
inventories= inventory.copy()

# %%
inventories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  1000 non-null   int64
#  1   film_id       1000 non-null   int64
#  2   store_id      1000 non-null   int64
#  3   last_update   1000 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
inventories.tail(50)
# Out:
#      inventory_id  film_id  store_id          last_update
# 950           951      212         1  2006-02-15 05:09:17
# 951           952      212         1  2006-02-15 05:09:17
# 952           953      212         2  2006-02-15 05:09:17
# 953           954      212         2  2006-02-15 05:09:17
# 954           955      213         1  2006-02-15 05:09:17
# 955           956      213         1  2006-02-15 05:09:17
# 956           957      213         1  2006-02-15 05:09:17
# 957           958      213         1  2006-02-15 05:09:17
# 958           959      214         2  2006-02-15 05:09:17
# 959           960      214         2  2006-02-15 05:09:17
# 960           961      214         2  2006-02-15 05:09:17
# 961           962      214         2  2006-02-15 05:09:17
# 962           963      215         1  2006-02-15 05:09:17
# 963           964      215         1  2006-02-15 05:09:17
# 964           965      215         1  2006-02-15 05:09:17
# ...

# %%
language= pd.read_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\data\language.csv')

# %%
languages= language.copy()

# %%
languages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   language_id  6 non-null      int64
#  1   name         6 non-null      object
#  2   last_update  6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 272.0+ bytes

# %%
languages
# Out:
#    language_id      name          last_update
# 0            1   English  2006-02-15 05:02:19
# 1            2   Italian  2006-02-15 05:02:19
# 2            3  Japanese  2006-02-15 05:02:19
# 3            4  Mandarin  2006-02-15 05:02:19
# 4            5    French  2006-02-15 05:02:19
# 5            6    German  2006-02-15 05:02:19

# %%
old_HDD=pd.read_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\data\old_HDD.csv')

# %%
old_HDDs= old_HDD.copy()

# %%
old_HDDs.head(50)
# Out:
#    first_name last_name                  title  release_year  category_id
# 0    PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1    PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2    PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3    PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4    PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# 5    PENELOPE   GUINESS     COLOR PHILADELPHIA          2006            4
# 6    PENELOPE   GUINESS        ELEPHANT TROJAN          2006           11
# 7    PENELOPE   GUINESS    GLEAMING JAWBREAKER          2006           15
# 8    PENELOPE   GUINESS         HUMAN GRAFFITI          2006           10
# 9    PENELOPE   GUINESS         KING EVOLUTION          2006            8
# 10   PENELOPE   GUINESS             LADY STAGE          2006           11
# 11   PENELOPE   GUINESS        LANGUAGE COWBOY          2006            3
# ...

# %%
rental=pd.read_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\data\rental.csv')

# %%
rentals= rental.copy()

# %%
rentals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rental_id     1000 non-null   int64
#  1   rental_date   1000 non-null   object
#  2   inventory_id  1000 non-null   int64
#  3   customer_id   1000 non-null   int64
#  4   return_date   1000 non-null   object
#  5   staff_id      1000 non-null   int64
#  6   last_update   1000 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 54.8+ KB

# %%
rentals.head(50).sort_values(by='inventory_id',ascending=False)
# Out:
#     rental_id          rental_date  inventory_id  customer_id  \
# 30         31  2005-05-25 04:05:17          4482          369
# 38         39  2005-05-25 04:51:46          4466          207
# 10         11  2005-05-25 00:09:02          4443          142
# 22         23  2005-05-25 02:40:21          4441          438
# 25         26  2005-05-25 03:36:50          4371          371
# 27         28  2005-05-25 03:42:37          4068          232
# 6           7  2005-05-24 23:11:53          3995          269
# 24         25  2005-05-25 03:21:20          3961           37
# 31         32  2005-05-25 04:06:21          3832          230
# 29         30  2005-05-25 04:01:32          3744          430
# 19         20  2005-05-25 01:48:41          3517          185
# 17         18  2005-05-25 01:10:47          3376           19
# 45         46  2005-05-25 06:04:08          3318            7
# 23         24  2005-05-25 02:53:02          3273          350
# ...

# %% [markdown]
# ## PASO 2: CONCLUSIONES DEL ANÁLISIS
#
# 1. A simple vista, tras consultarnos entre todos, hemos concluido que las bases de datos están bastante limpias.
#
#
#
# 2. De antemano, hemos comprobado que todos los data frame tienen una clave que hará posibles los joins en la posterior
#     fase de SQL.
#
#
#
# 3. Solo  hemos encontrado dos problemas esenciales:
#     3.1. Tenemos una columna de nulos en el dataframe de films que hay que eliminar.
#     3.2. Vamos a eliminar la columna de last update de todos los dataframe ya que no aporta ninguna información.

# %%
# El primer paso es eliminar las columnas con last update y nulos de film.

# %%
rentals.drop('last_update', axis=1, inplace= True)

# %%
films.drop(columns = 'original_language_id', axis=1, inplace = True)

# %%
films.drop(columns = 'last_update', axis=1, inplace = True)

# %%
actors.drop('last_update', axis=1, inplace = True)

# %%
categories.drop('last_update', axis=1, inplace = True)

# %%
inventories.drop(columns = 'last_update', axis=1, inplace = True)

# %%
languages.drop(columns = 'last_update', axis=1, inplace = True)

# %% [markdown]
# ## PASO 3: EXPORTACIÓN

# %%
films.to_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\films.csv', index=False)

# %%
actors.to_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\actors.csv', index=False)

# %%
categories.to_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\categories.csv', index=False)

# %%
inventories.to_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\inventories.csv', index=False)

# %%
languages.to_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\languages.csv', index=False)

# %%
rentals.to_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\rentals.csv', index=False)

# %%
old_HDDs.to_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Proyectos\w3-database-project\old_HDDs.csv', index=False)
